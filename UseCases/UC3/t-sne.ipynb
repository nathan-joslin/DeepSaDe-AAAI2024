# %%
from models import *
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, accuracy_score
from scoop import futures
import argparse
import os
import idx2numpy
from itertools import chain
import pickle

# %%
def data_processing(data):
    data.dropna(inplace=True)
    data.reset_index(drop=True, inplace=True)
    categorical_features = list(data.select_dtypes(include='object').columns)
    categorical_features = list(set(categorical_features))
    numerical_features = [c for c in data.columns if c not in categorical_features]
    scaler = MinMaxScaler()
    data[numerical_features] = scaler.fit_transform(data[numerical_features])

    for _c in categorical_features:
        data[_c] = pd.Categorical(data[_c])
    df_transformed = pd.get_dummies(data, drop_first=False)
    return df_transformed, scaler

def add_violations(X, y, count=40):
    indices = list(np.where((X.T[12] == 1))[0])
    instances_to_change = random.sample(indices, count)
    for i in instances_to_change:
        new_positive = random.randint(0, 2)
        new_y = [0]*5
        new_y[new_positive] = 1
        y[i] = np.array(new_y)

        
def get_violations(pred, X):
    indices = np.where((X.T[12] == 1))[0]
    pred_pop = pred[indices].T[3]
    pred_rock = pred[indices].T[4]
    pred_pop_or_rock = pred_pop + pred_rock
    return len(indices) - sum(pred_pop_or_rock)

# %%
dataset = 'music_data_24122020.csv'
dataset = pd.read_csv(dataset).iloc[:, 1:]
np.unique(dataset['Music Style'].tolist())
# Out:
# array(['Classical', 'Electronic', 'Metal', 'Pop', 'Rock'], dtype='<U10')

# %%
seed = 5
OUTER_FOLDS = 5

random.seed(100 + seed)
torch.manual_seed(100 + seed)
np.random.seed(100 + seed)
    
    
dataset = 'music_data_24122020.csv'
dataset = pd.read_csv(dataset).iloc[:, 1:]
dataset, scaler = data_processing(dataset)
y = np.array(dataset.iloc[:, -5:], dtype=np.float32)
X = np.array(dataset.iloc[:, :-5], dtype=np.float32)
add_violations(X, y, 60)
y = np.array(y, dtype=np.float32)

# number of folds for cross-validation
kf = KFold(n_splits=OUTER_FOLDS, shuffle=True, random_state=random.randint(0, 1000))
split_data = list(kf.split(X))

# %%
import torch.nn.functional as F

def input_last_layer(model, X):
    out = X
    for i in range(len(model.Layers) - 1):
        out = model.Layers[i](out)
        out = F.relu(out)
    return out.detach().numpy()

# %%
i = 1
for train_index, test_index in split_data:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    print(get_violations(y_train, X_train))
    print(get_violations(y_test, X_test))
    if i == 1:
        sys.exit(0)
    i += 1
# Out:
# 51.0
# 10.0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /cw/dtaijupiter/NoCsBack/dtai/kshitij/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3426: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# unconstrained model
unconstrained_model = MusicRegularizedModel(sizes=[13, 50, 30, 10, 5])
unconstrained_model.learn(X_train, y_train, learning_rate=0.1, batch_size=5, epochs=300,
                          momentum=0, K=K, alpha=0, validation_set_ratio=0.1, loss_type='srb')
# Out:
# epoch 1, validation loss: 0.5758939981460571; training loss: 0.5739101767539978; best loss: 0.5758939981460571
# epoch 2, validation loss: 0.5062366127967834; training loss: 0.506457507610321; best loss: 0.5062366127967834
# epoch 3, validation loss: 0.4920218884944916; training loss: 0.4898495674133301; best loss: 0.4920218884944916
# epoch 4, validation loss: 0.49027854204177856; training loss: 0.4868735373020172; best loss: 0.49027854204177856
# epoch 5, validation loss: 0.48521509766578674; training loss: 0.483405202627182; best loss: 0.48521509766578674
# epoch 6, validation loss: 0.4788568317890167; training loss: 0.4772658944129944; best loss: 0.4788568317890167
# epoch 7, validation loss: 0.46362558007240295; training loss: 0.4627443552017212; best loss: 0.46362558007240295
# epoch 8, validation loss: 0.42948293685913086; training loss: 0.43277424573898315; best loss: 0.42948293685913086
# epoch 9, validation loss: 0.3894917070865631; training loss: 0.39699873328208923; best loss: 0.3894917070865631
# epoch 10, validation loss: 0.36383411288261414; training loss: 0.3753398358821869; best loss: 0.36383411288261414
# epoch 11, validation loss: 0.3492100238800049; training loss: 0.3621251881122589; best loss: 0.3492100238800049
# epoch 12, validation loss: 0.33774831891059875; training loss: 0.35277506709098816; best loss: 0.33774831891059875
# epoch 13, validation loss: 0.32867705821990967; training loss: 0.34432604908943176; best loss: 0.32867705821990967
# epoch 14, validation loss: 0.31942448019981384; training loss: 0.3368481397628784; best loss: 0.31942448019981384
# epoch 15, validation loss: 0.3143664598464966; training loss: 0.33104798197746277; best loss: 0.3143664598464966
# epoch 16, validation loss: 0.30727747082710266; training loss: 0.32516807317733765; best loss: 0.30727747082710266
# epoch 17, validation loss: 0.29653069376945496; training loss: 0.31673958897590637; best loss: 0.29653069376945496
# epoch 18, validation loss: 0.28594744205474854; training loss: 0.30823829770088196; best loss: 0.28594744205474854
# epoch 19, validation loss: 0.2729922831058502; training loss: 0.29569166898727417; best loss: 0.2729922831058502
# epoch 20, validation loss: 0.2629638910293579; training loss: 0.28578948974609375; best loss: 0.2629638910293579
# epoch 21, validation loss: 0.2590692639350891; training loss: 0.28527185320854187; best loss: 0.2590692639350891
# epoch 22, validation loss: 0.2471398264169693; training loss: 0.2711048722267151; best loss: 0.2471398264169693
# epoch 23, validation loss: 0.24642270803451538; training loss: 0.2724672555923462; best loss: 0.24642270803451538
# epoch 24, validation loss: 0.23899979889392853; training loss: 0.26128941774368286; best loss: 0.23899979889392853
# epoch 25, validation loss: 0.22237353026866913; training loss: 0.2592066526412964; best loss: 0.22237353026866913
# epoch 26, validation loss: 0.235625222325325; training loss: 0.2705971598625183; best loss: 0.22237353026866913
# epoch 27, validation loss: 0.23030713200569153; training loss: 0.2513846457004547; best loss: 0.22237353026866913
# epoch 28, validation loss: 0.24102628231048584; training loss: 0.25714999437332153; best loss: 0.22237353026866913
# epoch 29, validation loss: 0.22158217430114746; training loss: 0.24359363317489624; best loss: 0.22158217430114746
# epoch 30, validation loss: 0.21277010440826416; training loss: 0.2393455058336258; best loss: 0.21277010440826416
# epoch 31, validation loss: 0.2173255831003189; training loss: 0.24163605272769928; best loss: 0.21277010440826416
# epoch 32, validation loss: 0.2177474945783615; training loss: 0.2387443333864212; best loss: 0.21277010440826416
# epoch 33, validation loss: 0.2060995250940323; training loss: 0.2330690175294876; best loss: 0.2060995250940323
# epoch 34, validation loss: 0.20413607358932495; training loss: 0.2286423146724701; best loss: 0.20413607358932495
# epoch 35, validation loss: 0.3257324695587158; training loss: 0.36488646268844604; best loss: 0.20413607358932495
# epoch 36, validation loss: 0.2341798096895218; training loss: 0.2523106634616852; best loss: 0.20413607358932495
# epoch 37, validation loss: 0.200440913438797; training loss: 0.22836123406887054; best loss: 0.200440913438797
# epoch 38, validation loss: 0.20132191479206085; training loss: 0.22269102931022644; best loss: 0.200440913438797
# epoch 39, validation loss: 0.2026728242635727; training loss: 0.23416411876678467; best loss: 0.200440913438797
# epoch 40, validation loss: 0.2011612504720688; training loss: 0.2233794778585434; best loss: 0.200440913438797
# epoch 41, validation loss: 0.21608056128025055; training loss: 0.232963427901268; best loss: 0.200440913438797
# epoch 42, validation loss: 0.2067037671804428; training loss: 0.2262255847454071; best loss: 0.200440913438797
# epoch 43, validation loss: 0.2017429918050766; training loss: 0.23341532051563263; best loss: 0.200440913438797
# epoch 44, validation loss: 0.205225870013237; training loss: 0.22130905091762543; best loss: 0.200440913438797
# epoch 45, validation loss: 0.20075765252113342; training loss: 0.21960508823394775; best loss: 0.200440913438797
# epoch 46, validation loss: 0.21215638518333435; training loss: 0.22695410251617432; best loss: 0.200440913438797
# epoch 47, validation loss: 0.19362403452396393; training loss: 0.21775799989700317; best loss: 0.19362403452396393
# epoch 48, validation loss: 0.20123964548110962; training loss: 0.21608403325080872; best loss: 0.19362403452396393
# epoch 49, validation loss: 0.1882297396659851; training loss: 0.21540714800357819; best loss: 0.1882297396659851
# epoch 50, validation loss: 0.18999716639518738; training loss: 0.21243859827518463; best loss: 0.1882297396659851
# epoch 51, validation loss: 0.2138030081987381; training loss: 0.22931750118732452; best loss: 0.1882297396659851
# epoch 52, validation loss: 0.19332030415534973; training loss: 0.21173961460590363; best loss: 0.1882297396659851
# epoch 53, validation loss: 0.18622495234012604; training loss: 0.21352773904800415; best loss: 0.18622495234012604
# epoch 54, validation loss: 0.1947128027677536; training loss: 0.21395675837993622; best loss: 0.18622495234012604
# epoch 55, validation loss: 0.19594186544418335; training loss: 0.22580668330192566; best loss: 0.18622495234012604
# epoch 56, validation loss: 0.1989951878786087; training loss: 0.23050522804260254; best loss: 0.18622495234012604
# epoch 57, validation loss: 0.19976286590099335; training loss: 0.21376007795333862; best loss: 0.18622495234012604
# epoch 58, validation loss: 0.21985994279384613; training loss: 0.23790039122104645; best loss: 0.18622495234012604
# epoch 59, validation loss: 0.21207299828529358; training loss: 0.21719613671302795; best loss: 0.18622495234012604
# epoch 60, validation loss: 0.1941257119178772; training loss: 0.2089717835187912; best loss: 0.18622495234012604
# epoch 61, validation loss: 0.19682209193706512; training loss: 0.21072854101657867; best loss: 0.18622495234012604
# epoch 62, validation loss: 0.1960141360759735; training loss: 0.20927554368972778; best loss: 0.18622495234012604
# epoch 63, validation loss: 0.19145232439041138; training loss: 0.20823276042938232; best loss: 0.18622495234012604
# epoch 64, validation loss: 0.3108274042606354; training loss: 0.28990697860717773; best loss: 0.18622495234012604
# epoch 65, validation loss: 0.22406578063964844; training loss: 0.22428344190120697; best loss: 0.18622495234012604
# epoch 66, validation loss: 0.187016099691391; training loss: 0.2110685110092163; best loss: 0.18622495234012604
# epoch 67, validation loss: 0.19168759882450104; training loss: 0.20680168271064758; best loss: 0.18622495234012604
# epoch 68, validation loss: 0.19446028769016266; training loss: 0.2069683074951172; best loss: 0.18622495234012604
# epoch 69, validation loss: 0.1979866325855255; training loss: 0.20839861035346985; best loss: 0.18622495234012604
# epoch 70, validation loss: 0.18440033495426178; training loss: 0.20538866519927979; best loss: 0.18440033495426178
# epoch 71, validation loss: 0.18685835599899292; training loss: 0.20522478222846985; best loss: 0.18440033495426178
# epoch 72, validation loss: 0.2116403430700302; training loss: 0.24140000343322754; best loss: 0.18440033495426178
# epoch 73, validation loss: 0.20544777810573578; training loss: 0.21579597890377045; best loss: 0.18440033495426178
# epoch 74, validation loss: 0.22451680898666382; training loss: 0.22581005096435547; best loss: 0.18440033495426178
# epoch 75, validation loss: 0.19676460325717926; training loss: 0.20704852044582367; best loss: 0.18440033495426178
# epoch 76, validation loss: 0.24089081585407257; training loss: 0.27766576409339905; best loss: 0.18440033495426178
# epoch 77, validation loss: 0.20993633568286896; training loss: 0.2149486094713211; best loss: 0.18440033495426178
# epoch 78, validation loss: 0.18883997201919556; training loss: 0.208206444978714; best loss: 0.18440033495426178
# epoch 79, validation loss: 0.1906544715166092; training loss: 0.21202275156974792; best loss: 0.18440033495426178
# epoch 80, validation loss: 0.18789339065551758; training loss: 0.2044222354888916; best loss: 0.18440033495426178
# epoch 81, validation loss: 0.19499683380126953; training loss: 0.2091742604970932; best loss: 0.18440033495426178
# epoch 82, validation loss: 0.19590064883232117; training loss: 0.2070339024066925; best loss: 0.18440033495426178
# epoch 83, validation loss: 0.1950652301311493; training loss: 0.20419158041477203; best loss: 0.18440033495426178
# epoch 84, validation loss: 0.18184547126293182; training loss: 0.20859947800636292; best loss: 0.18184547126293182
# epoch 85, validation loss: 0.1906593143939972; training loss: 0.20607052743434906; best loss: 0.18184547126293182
# epoch 86, validation loss: 0.2320992648601532; training loss: 0.23037199676036835; best loss: 0.18184547126293182
# epoch 87, validation loss: 0.19160765409469604; training loss: 0.2026478499174118; best loss: 0.18184547126293182
# epoch 88, validation loss: 0.18130284547805786; training loss: 0.2035706490278244; best loss: 0.18130284547805786
# epoch 89, validation loss: 0.1910165399312973; training loss: 0.20571547746658325; best loss: 0.18130284547805786
# epoch 90, validation loss: 0.19347967207431793; training loss: 0.20630806684494019; best loss: 0.18130284547805786
# epoch 91, validation loss: 0.18476013839244843; training loss: 0.20086103677749634; best loss: 0.18130284547805786
# epoch 92, validation loss: 0.1919679045677185; training loss: 0.20163916051387787; best loss: 0.18130284547805786
# epoch 93, validation loss: 0.18556751310825348; training loss: 0.20352347195148468; best loss: 0.18130284547805786
# epoch 94, validation loss: 0.20190657675266266; training loss: 0.21542096138000488; best loss: 0.18130284547805786
# epoch 95, validation loss: 0.20127812027931213; training loss: 0.21161234378814697; best loss: 0.18130284547805786
# epoch 96, validation loss: 0.19902433454990387; training loss: 0.20407772064208984; best loss: 0.18130284547805786
# epoch 97, validation loss: 0.18660664558410645; training loss: 0.20281048119068146; best loss: 0.18130284547805786
# epoch 98, validation loss: 0.1851177215576172; training loss: 0.19999317824840546; best loss: 0.18130284547805786
# epoch 99, validation loss: 0.1955658495426178; training loss: 0.20462435483932495; best loss: 0.18130284547805786
# epoch 100, validation loss: 0.19050835072994232; training loss: 0.20024852454662323; best loss: 0.18130284547805786
# epoch 101, validation loss: 0.19545750319957733; training loss: 0.2029307335615158; best loss: 0.18130284547805786
# epoch 102, validation loss: 0.18499992787837982; training loss: 0.20270772278308868; best loss: 0.18130284547805786
# epoch 103, validation loss: 0.1848633587360382; training loss: 0.20370785892009735; best loss: 0.18130284547805786
# epoch 104, validation loss: 0.1830166131258011; training loss: 0.20202842354774475; best loss: 0.18130284547805786
# epoch 105, validation loss: 0.18749098479747772; training loss: 0.1986001878976822; best loss: 0.18130284547805786
# epoch 106, validation loss: 0.18439693748950958; training loss: 0.19921264052391052; best loss: 0.18130284547805786
# epoch 107, validation loss: 0.19013839960098267; training loss: 0.19990335404872894; best loss: 0.18130284547805786
# epoch 108, validation loss: 0.18395452201366425; training loss: 0.19830508530139923; best loss: 0.18130284547805786
# epoch 109, validation loss: 0.18381525576114655; training loss: 0.20054061710834503; best loss: 0.18130284547805786
# epoch 110, validation loss: 0.18967457115650177; training loss: 0.20193986594676971; best loss: 0.18130284547805786
# epoch 111, validation loss: 0.20044873654842377; training loss: 0.20843704044818878; best loss: 0.18130284547805786
# epoch 112, validation loss: 0.194772407412529; training loss: 0.2134912759065628; best loss: 0.18130284547805786
# epoch 113, validation loss: 0.19518154859542847; training loss: 0.20150558650493622; best loss: 0.18130284547805786
# epoch 114, validation loss: 0.1947825700044632; training loss: 0.20033082365989685; best loss: 0.18130284547805786
# epoch 115, validation loss: 0.1881912499666214; training loss: 0.1977940946817398; best loss: 0.18130284547805786
# epoch 116, validation loss: 0.19282913208007812; training loss: 0.20618338882923126; best loss: 0.18130284547805786
# epoch 117, validation loss: 0.19713711738586426; training loss: 0.20281806588172913; best loss: 0.18130284547805786
# epoch 118, validation loss: 0.1934126913547516; training loss: 0.1984032541513443; best loss: 0.18130284547805786
# epoch 119, validation loss: 0.18647316098213196; training loss: 0.19804298877716064; best loss: 0.18130284547805786
# epoch 120, validation loss: 0.19070492684841156; training loss: 0.1979624330997467; best loss: 0.18130284547805786
# epoch 121, validation loss: 0.18338197469711304; training loss: 0.19623467326164246; best loss: 0.18130284547805786
# epoch 122, validation loss: 0.2130570113658905; training loss: 0.21462582051753998; best loss: 0.18130284547805786
# epoch 123, validation loss: 0.20114673674106598; training loss: 0.20429663360118866; best loss: 0.18130284547805786
# epoch 124, validation loss: 0.19997744262218475; training loss: 0.2181701958179474; best loss: 0.18130284547805786
# epoch 125, validation loss: 0.19091424345970154; training loss: 0.20375758409500122; best loss: 0.18130284547805786
# epoch 126, validation loss: 0.21337217092514038; training loss: 0.21061605215072632; best loss: 0.18130284547805786
# epoch 127, validation loss: 0.198485866189003; training loss: 0.2006559520959854; best loss: 0.18130284547805786
# epoch 128, validation loss: 0.18456408381462097; training loss: 0.20038940012454987; best loss: 0.18130284547805786
# epoch 129, validation loss: 0.18808084726333618; training loss: 0.1951056271791458; best loss: 0.18130284547805786
# epoch 130, validation loss: 0.1980515718460083; training loss: 0.19963793456554413; best loss: 0.18130284547805786
# epoch 131, validation loss: 0.195469930768013; training loss: 0.19906771183013916; best loss: 0.18130284547805786
# epoch 132, validation loss: 0.19370634853839874; training loss: 0.2075740396976471; best loss: 0.18130284547805786
# epoch 133, validation loss: 0.1940646469593048; training loss: 0.19986732304096222; best loss: 0.18130284547805786
# epoch 134, validation loss: 0.1841348558664322; training loss: 0.19569987058639526; best loss: 0.18130284547805786
# epoch 135, validation loss: 0.18685190379619598; training loss: 0.20318816602230072; best loss: 0.18130284547805786
# epoch 136, validation loss: 0.18461094796657562; training loss: 0.19491691887378693; best loss: 0.18130284547805786
# epoch 137, validation loss: 0.1821303814649582; training loss: 0.19542516767978668; best loss: 0.18130284547805786
# epoch 138, validation loss: 0.17945271730422974; training loss: 0.19562295079231262; best loss: 0.17945271730422974
# epoch 139, validation loss: 0.19058753550052643; training loss: 0.20119640231132507; best loss: 0.17945271730422974
# epoch 140, validation loss: 0.20836487412452698; training loss: 0.20426170527935028; best loss: 0.17945271730422974
# epoch 141, validation loss: 0.183783158659935; training loss: 0.193362757563591; best loss: 0.17945271730422974
# epoch 142, validation loss: 0.1850128173828125; training loss: 0.1935071349143982; best loss: 0.17945271730422974
# epoch 143, validation loss: 0.18368571996688843; training loss: 0.19293567538261414; best loss: 0.17945271730422974
# epoch 144, validation loss: 0.20989224314689636; training loss: 0.22711428999900818; best loss: 0.17945271730422974
# epoch 145, validation loss: 0.18382105231285095; training loss: 0.19553051888942719; best loss: 0.17945271730422974
# epoch 146, validation loss: 0.18943069875240326; training loss: 0.19456511735916138; best loss: 0.17945271730422974
# epoch 147, validation loss: 0.18271362781524658; training loss: 0.19293902814388275; best loss: 0.17945271730422974
# epoch 148, validation loss: 0.1890653371810913; training loss: 0.19302116334438324; best loss: 0.17945271730422974
# epoch 149, validation loss: 0.1911150962114334; training loss: 0.19425688683986664; best loss: 0.17945271730422974
# epoch 150, validation loss: 0.19058316946029663; training loss: 0.1951233446598053; best loss: 0.17945271730422974
# epoch 151, validation loss: 0.2044948935508728; training loss: 0.20498251914978027; best loss: 0.17945271730422974
# epoch 152, validation loss: 0.18402081727981567; training loss: 0.19114741683006287; best loss: 0.17945271730422974
# epoch 153, validation loss: 0.19893546402454376; training loss: 0.20268118381500244; best loss: 0.17945271730422974
# epoch 154, validation loss: 0.19319821894168854; training loss: 0.19575746357440948; best loss: 0.17945271730422974
# epoch 155, validation loss: 0.1910487413406372; training loss: 0.19439223408699036; best loss: 0.17945271730422974
# epoch 156, validation loss: 0.1857282668352127; training loss: 0.19433754682540894; best loss: 0.17945271730422974
# epoch 157, validation loss: 0.18548674881458282; training loss: 0.19579505920410156; best loss: 0.17945271730422974
# epoch 158, validation loss: 0.20818611979484558; training loss: 0.20737749338150024; best loss: 0.17945271730422974
# epoch 159, validation loss: 0.19119276106357574; training loss: 0.19140300154685974; best loss: 0.17945271730422974
# epoch 160, validation loss: 0.18322528898715973; training loss: 0.1925879567861557; best loss: 0.17945271730422974
# epoch 161, validation loss: 0.1913730800151825; training loss: 0.2040419578552246; best loss: 0.17945271730422974
# epoch 162, validation loss: 0.18447540700435638; training loss: 0.19645637273788452; best loss: 0.17945271730422974
# epoch 163, validation loss: 0.19558653235435486; training loss: 0.19845962524414062; best loss: 0.17945271730422974
# epoch 164, validation loss: 0.18008755147457123; training loss: 0.18903924524784088; best loss: 0.17945271730422974
# epoch 165, validation loss: 0.2037251740694046; training loss: 0.20759941637516022; best loss: 0.17945271730422974
# epoch 166, validation loss: 0.18264281749725342; training loss: 0.18968571722507477; best loss: 0.17945271730422974
# epoch 167, validation loss: 0.1827033907175064; training loss: 0.19129924476146698; best loss: 0.17945271730422974
# epoch 168, validation loss: 0.18195068836212158; training loss: 0.19104275107383728; best loss: 0.17945271730422974
# epoch 169, validation loss: 0.17897532880306244; training loss: 0.19327208399772644; best loss: 0.17897532880306244
# epoch 170, validation loss: 0.18928107619285583; training loss: 0.19188572466373444; best loss: 0.17897532880306244
# epoch 171, validation loss: 0.20267045497894287; training loss: 0.1976167857646942; best loss: 0.17897532880306244
# epoch 172, validation loss: 0.1830185204744339; training loss: 0.18974946439266205; best loss: 0.17897532880306244
# epoch 173, validation loss: 0.18362362682819366; training loss: 0.19095619022846222; best loss: 0.17897532880306244
# epoch 174, validation loss: 0.18431498110294342; training loss: 0.19073128700256348; best loss: 0.17897532880306244
# epoch 175, validation loss: 0.18518805503845215; training loss: 0.19445565342903137; best loss: 0.17897532880306244
# epoch 176, validation loss: 0.17753435671329498; training loss: 0.1890719085931778; best loss: 0.17753435671329498
# epoch 177, validation loss: 0.19197608530521393; training loss: 0.19739778339862823; best loss: 0.17753435671329498
# epoch 178, validation loss: 0.18655383586883545; training loss: 0.1905408352613449; best loss: 0.17753435671329498
# epoch 179, validation loss: 0.18226756155490875; training loss: 0.1922711730003357; best loss: 0.17753435671329498
# epoch 180, validation loss: 0.20208485424518585; training loss: 0.19717620313167572; best loss: 0.17753435671329498
# epoch 181, validation loss: 0.18773411214351654; training loss: 0.19378319382667542; best loss: 0.17753435671329498
# epoch 182, validation loss: 0.18264825642108917; training loss: 0.18749700486660004; best loss: 0.17753435671329498
# epoch 183, validation loss: 0.1806049942970276; training loss: 0.19040469825267792; best loss: 0.17753435671329498
# epoch 184, validation loss: 0.18053047358989716; training loss: 0.18751800060272217; best loss: 0.17753435671329498
# epoch 185, validation loss: 0.18518179655075073; training loss: 0.18911483883857727; best loss: 0.17753435671329498
# epoch 186, validation loss: 0.21132676303386688; training loss: 0.20839159190654755; best loss: 0.17753435671329498
# epoch 187, validation loss: 0.19025008380413055; training loss: 0.1894589364528656; best loss: 0.17753435671329498
# epoch 188, validation loss: 0.20269407331943512; training loss: 0.1992189884185791; best loss: 0.17753435671329498
# epoch 189, validation loss: 0.17835910618305206; training loss: 0.18675272166728973; best loss: 0.17753435671329498
# epoch 190, validation loss: 0.17971237003803253; training loss: 0.18779926002025604; best loss: 0.17753435671329498
# epoch 191, validation loss: 0.21045178174972534; training loss: 0.23479709029197693; best loss: 0.17753435671329498
# epoch 192, validation loss: 0.19552290439605713; training loss: 0.1924053281545639; best loss: 0.17753435671329498
# epoch 193, validation loss: 0.1895725131034851; training loss: 0.18917644023895264; best loss: 0.17753435671329498
# epoch 194, validation loss: 0.1832093447446823; training loss: 0.1923600286245346; best loss: 0.17753435671329498
# epoch 195, validation loss: 0.1874443143606186; training loss: 0.18720927834510803; best loss: 0.17753435671329498
# epoch 196, validation loss: 0.17661374807357788; training loss: 0.18725703656673431; best loss: 0.17661374807357788
# epoch 197, validation loss: 0.18265442550182343; training loss: 0.19102193415164948; best loss: 0.17661374807357788
# epoch 198, validation loss: 0.1911790817975998; training loss: 0.18870416283607483; best loss: 0.17661374807357788
# epoch 199, validation loss: 0.18252217769622803; training loss: 0.18736864626407623; best loss: 0.17661374807357788
# epoch 200, validation loss: 0.1801372766494751; training loss: 0.1870025247335434; best loss: 0.17661374807357788
# epoch 201, validation loss: 0.1936773955821991; training loss: 0.19555728137493134; best loss: 0.17661374807357788
# epoch 202, validation loss: 0.18349803984165192; training loss: 0.18797343969345093; best loss: 0.17661374807357788
# epoch 203, validation loss: 0.18189449608325958; training loss: 0.1847832053899765; best loss: 0.17661374807357788
# epoch 204, validation loss: 0.18874743580818176; training loss: 0.1930411010980606; best loss: 0.17661374807357788
# epoch 205, validation loss: 0.1949920505285263; training loss: 0.18953202664852142; best loss: 0.17661374807357788
# epoch 206, validation loss: 0.17936453223228455; training loss: 0.1854080855846405; best loss: 0.17661374807357788
# epoch 207, validation loss: 0.18494509160518646; training loss: 0.1854465752840042; best loss: 0.17661374807357788
# epoch 208, validation loss: 0.17866815626621246; training loss: 0.18386505544185638; best loss: 0.17661374807357788
# epoch 209, validation loss: 0.18147291243076324; training loss: 0.19460684061050415; best loss: 0.17661374807357788
# epoch 210, validation loss: 0.18697147071361542; training loss: 0.18735088407993317; best loss: 0.17661374807357788
# epoch 211, validation loss: 0.17793096601963043; training loss: 0.18610498309135437; best loss: 0.17661374807357788
# epoch 212, validation loss: 0.18674933910369873; training loss: 0.18856282532215118; best loss: 0.17661374807357788
# epoch 213, validation loss: 0.18656207621097565; training loss: 0.18686984479427338; best loss: 0.17661374807357788
# epoch 214, validation loss: 0.17952127754688263; training loss: 0.1849021464586258; best loss: 0.17661374807357788
# epoch 215, validation loss: 0.17953842878341675; training loss: 0.18730220198631287; best loss: 0.17661374807357788
# epoch 216, validation loss: 0.18851338326931; training loss: 0.19168539345264435; best loss: 0.17661374807357788
# epoch 217, validation loss: 0.18459200859069824; training loss: 0.18429480493068695; best loss: 0.17661374807357788
# epoch 218, validation loss: 0.18798401951789856; training loss: 0.18467694520950317; best loss: 0.17661374807357788
# epoch 219, validation loss: 0.18026761710643768; training loss: 0.18261310458183289; best loss: 0.17661374807357788
# epoch 220, validation loss: 0.1839614063501358; training loss: 0.1868230551481247; best loss: 0.17661374807357788
# epoch 221, validation loss: 0.18660959601402283; training loss: 0.19111229479312897; best loss: 0.17661374807357788
# epoch 222, validation loss: 0.1757468581199646; training loss: 0.18422116339206696; best loss: 0.1757468581199646
# epoch 223, validation loss: 0.18101440370082855; training loss: 0.18447420001029968; best loss: 0.1757468581199646
# epoch 224, validation loss: 0.187811478972435; training loss: 0.18455363810062408; best loss: 0.1757468581199646
# epoch 225, validation loss: 0.2025003880262375; training loss: 0.20297947525978088; best loss: 0.1757468581199646
# epoch 226, validation loss: 0.1785431206226349; training loss: 0.19975370168685913; best loss: 0.1757468581199646
# epoch 227, validation loss: 0.18019288778305054; training loss: 0.19539287686347961; best loss: 0.1757468581199646
# epoch 228, validation loss: 0.18948259949684143; training loss: 0.18695470690727234; best loss: 0.1757468581199646
# epoch 229, validation loss: 0.18121321499347687; training loss: 0.18885014951229095; best loss: 0.1757468581199646
# epoch 230, validation loss: 0.18649080395698547; training loss: 0.18182839453220367; best loss: 0.1757468581199646
# epoch 231, validation loss: 0.256561279296875; training loss: 0.3072870671749115; best loss: 0.1757468581199646
# epoch 232, validation loss: 0.18485228717327118; training loss: 0.18644391000270844; best loss: 0.1757468581199646
# epoch 233, validation loss: 0.17969867587089539; training loss: 0.18311598896980286; best loss: 0.1757468581199646
# epoch 234, validation loss: 0.18394944071769714; training loss: 0.19069163501262665; best loss: 0.1757468581199646
# epoch 235, validation loss: 0.19539807736873627; training loss: 0.19147589802742004; best loss: 0.1757468581199646
# epoch 236, validation loss: 0.19858647882938385; training loss: 0.1894572675228119; best loss: 0.1757468581199646
# epoch 237, validation loss: 0.18236418068408966; training loss: 0.18180660903453827; best loss: 0.1757468581199646
# epoch 238, validation loss: 0.1818845421075821; training loss: 0.18176445364952087; best loss: 0.1757468581199646
# epoch 239, validation loss: 0.18543940782546997; training loss: 0.18940389156341553; best loss: 0.1757468581199646
# epoch 240, validation loss: 0.21028931438922882; training loss: 0.20049956440925598; best loss: 0.1757468581199646
# epoch 241, validation loss: 0.18481944501399994; training loss: 0.18241839110851288; best loss: 0.1757468581199646
# epoch 242, validation loss: 0.19726860523223877; training loss: 0.1874951869249344; best loss: 0.1757468581199646
# epoch 243, validation loss: 0.18596278131008148; training loss: 0.18426725268363953; best loss: 0.1757468581199646
# epoch 244, validation loss: 0.19025449454784393; training loss: 0.18663622438907623; best loss: 0.1757468581199646
# epoch 245, validation loss: 0.1937815099954605; training loss: 0.1899649053812027; best loss: 0.1757468581199646
# epoch 246, validation loss: 0.2014000564813614; training loss: 0.23395223915576935; best loss: 0.1757468581199646
# epoch 247, validation loss: 0.19051584601402283; training loss: 0.1883118599653244; best loss: 0.1757468581199646
# epoch 248, validation loss: 0.19051259756088257; training loss: 0.1861436367034912; best loss: 0.1757468581199646
# epoch 249, validation loss: 0.18075020611286163; training loss: 0.1815716177225113; best loss: 0.1757468581199646
# epoch 250, validation loss: 0.1796511709690094; training loss: 0.18467791378498077; best loss: 0.1757468581199646
# epoch 251, validation loss: 0.18966802954673767; training loss: 0.1860639899969101; best loss: 0.1757468581199646
# epoch 252, validation loss: 0.1923374980688095; training loss: 0.18174834549427032; best loss: 0.1757468581199646
# epoch 253, validation loss: 0.19193299114704132; training loss: 0.1937168836593628; best loss: 0.1757468581199646
# epoch 254, validation loss: 0.19714714586734772; training loss: 0.19062350690364838; best loss: 0.1757468581199646
# epoch 255, validation loss: 0.18963707983493805; training loss: 0.18309584259986877; best loss: 0.1757468581199646
# epoch 256, validation loss: 0.18302513659000397; training loss: 0.18200038373470306; best loss: 0.1757468581199646
# epoch 257, validation loss: 0.1828121840953827; training loss: 0.1786673665046692; best loss: 0.1757468581199646
# epoch 258, validation loss: 0.18419821560382843; training loss: 0.17889592051506042; best loss: 0.1757468581199646
# epoch 259, validation loss: 0.19071120023727417; training loss: 0.18547852337360382; best loss: 0.1757468581199646
# epoch 260, validation loss: 0.18948809802532196; training loss: 0.17818443477153778; best loss: 0.1757468581199646
# epoch 261, validation loss: 0.20063556730747223; training loss: 0.1942421793937683; best loss: 0.1757468581199646
# epoch 262, validation loss: 0.18584899604320526; training loss: 0.17866462469100952; best loss: 0.1757468581199646
# epoch 263, validation loss: 0.19136174023151398; training loss: 0.18065594136714935; best loss: 0.1757468581199646
# epoch 264, validation loss: 0.2165755033493042; training loss: 0.1954413205385208; best loss: 0.1757468581199646
# epoch 265, validation loss: 0.18700379133224487; training loss: 0.17701217532157898; best loss: 0.1757468581199646
# epoch 266, validation loss: 0.18337076902389526; training loss: 0.1762322634458542; best loss: 0.1757468581199646
# epoch 267, validation loss: 0.23873983323574066; training loss: 0.233439639210701; best loss: 0.1757468581199646
# epoch 268, validation loss: 0.187962144613266; training loss: 0.17917680740356445; best loss: 0.1757468581199646
# epoch 269, validation loss: 0.19241663813591003; training loss: 0.1854844093322754; best loss: 0.1757468581199646
# epoch 270, validation loss: 0.187898188829422; training loss: 0.17719599604606628; best loss: 0.1757468581199646
# epoch 271, validation loss: 0.18941040337085724; training loss: 0.18055199086666107; best loss: 0.1757468581199646
# epoch 272, validation loss: 0.19750522077083588; training loss: 0.18638011813163757; best loss: 0.1757468581199646
# Finished Training

# %%
deepsade_model = torch.load('{}/deepsade_model_fold_{}.pt'.format(seed, i))

# %%
from sklearn.manifold import TSNE

def find_relevant_instances(X):
    indices = list(np.where((X.T[12] == 1))[0])
    return indices

def get_tsne_data(model, X_test):
    X_l = input_last_layer(model, torch.tensor(X_test))
    X_embedded = TSNE(n_components=2, init='random', perplexity=5).fit_transform(X_l)
    X_embedded = pd.DataFrame(X_embedded)
    X_embedded.columns = ['dim1', 'dim2']
    
    score = model(torch.tensor(X_test)).detach().numpy()
    pred = []
    for p in score:
        pred.append(np.argmax(p))
        pred_d = np.zeros((len(pred), len(score[0])))
        pred_d[np.arange(len(pred)), pred] = 1
    pred_d = np.array(pred_d)
    print(pred_d.sum(axis=0))
    print(get_violations(pred_d, X_test))
    
    predicted_genre = []
    for i in range(len(pred_d)):
        if pred_d[i][0] == 1:
            predicted_genre.append('classical')
        elif pred_d[i][1] == 1:
            predicted_genre.append('electronic')
        elif pred_d[i][2] == 1:
            predicted_genre.append('metal')
        elif pred_d[i][3] == 1:
            predicted_genre.append('pop')
        else:
            predicted_genre.append('rock')
    
    pop_rock_prediction_idx = [i for i in range(len(pred_d)) if (pred_d[i][3] == 1) or (pred_d[i][4] == 1)]
    beatles_idx = find_relevant_instances(X_test)
    X_embedded['beatles'] = 'no'
    X_embedded['pop-or-rock'] = 'no'
    X_embedded.loc[beatles_idx, 'beatles'] = 'yes'
    X_embedded.loc[pop_rock_prediction_idx, 'pop-or-rock'] = 'yes'
    X_embedded['predicted-genre'] = predicted_genre
    return X_embedded

# %%
X_test_tsne_deepsade = get_tsne_data(deepsade_model, X_test)
X_test_tsne_unconstrained = get_tsne_data(unconstrained_model, X_test)
# Out:
# [20. 26. 38. 36. 39.]
# 0.0
# [22. 25. 37. 41. 34.]
# 2.0

# %%
def big_chart(chart, fontsize = 20): 
    return chart.configure_axis(
        grid = True, 
    labelFontSize = fontsize,
    titleFontSize = fontsize
).configure_title(
    fontSize = fontsize
    ).configure_legend(
titleFontSize=fontsize,
labelFontSize=fontsize
).configure_view(
    strokeWidth=0
)

def small_chart(chart, fontsize=None): 
    return big_chart(chart.properties(width=150,
                             height=150
                            ), fontsize)

# %%
import altair as alt

c1 = alt.Chart(X_test_tsne_deepsade).mark_point().encode(
    x='dim1',
    y='dim2',
    color='beatles'
)

c2 = alt.Chart(X_test_tsne_deepsade).mark_point().encode(
    x='dim1',
    y='dim2',
    color='pop-or-rock'
)

c3 = alt.Chart(X_test_tsne_deepsade).mark_point().encode(
    x='dim1',
    y='dim2',
    color='predicted-genre'
)

big_chart(c1, fontsize=25)
# Out:
# alt.Chart(...)

# %%
big_chart(c2, fontsize=25)
# Out:
# alt.Chart(...)

# %%
c1_u = alt.Chart(X_test_tsne_unconstrained).mark_point().encode(
    x='dim1',
    y='dim2',
    color='beatles'
)

c2_u = alt.Chart(X_test_tsne_unconstrained).mark_point().encode(
    x='dim1',
    y='dim2',
    color='pop-or-rock'
)

c3_u = alt.Chart(X_test_tsne_unconstrained).mark_point().encode(
    x='dim1',
    y='dim2',
    color='predicted-genre'
)

big_chart(c1_u, fontsize=25)
# Out:
# alt.Chart(...)

# %%
big_chart(c2_u, fontsize=25)
# Out:
# alt.Chart(...)

# %%
X_embedded_2 = TSNE(n_components=2, init='random', perplexity=3).fit_transform(X_l)
X_embedded_2 = pd.DataFrame(X_embedded_2)
X_embedded_2.columns = ['dim1', 'dim2']

beatles_idx = find_relevant_instances(X_test)
X_embedded_2['beatles'] = 'no'
X_embedded_2['pop-or-rock'] = 'no'
X_embedded_2.loc[beatles_idx, 'beatles'] = 'yes'
X_embedded_2.loc[pop_rock_prediction_idx, 'pop-or-rock'] = 'yes'
X_embedded_2['predicted-genre'] = predicted_genre
X_embedded_2
# Out:
#           dim1       dim2 beatles pop-or-rock predicted-genre
# 0   -14.509541 -58.773964      no         yes            rock
# 1   -10.274336 -22.682421     yes         yes             pop
# 2   -28.612734   1.138877     yes         yes             pop
# 3     1.365832 -21.182203     yes         yes             pop
# 4   -19.620451  -7.197937     yes         yes             pop
# ..         ...        ...     ...         ...             ...
# 154  51.846794 -13.995423      no          no      electronic
# 155 -24.754915  -3.534508     yes         yes             pop
# 156 -29.966299   1.877599     yes         yes             pop
# 157  41.557880  37.750122      no          no           metal
# 158  42.469238  41.194820      no          no           metal
#
# [159 rows x 5 columns]

# %%
c1 = alt.Chart(X_embedded_2).mark_point().encode(
    x='dim1',
    y='dim2',
    color='beatles'
)
big_chart(c1, fontsize=25)
# Out:
# alt.Chart(...)
